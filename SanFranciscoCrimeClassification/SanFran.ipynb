# %% [markdown]
# # San Francisco Crime Classification
# ## Predict the category of crimes that occurred in the city by the bay
#
# From 1934 to 1963, San Francisco was infamous for housing some of the world's most notorious criminals on the inescapable island of Alcatraz.
#
# Today, the city is known more for its tech scene than its criminal past. But, with rising wealth inequality, housing shortages, and a proliferation of expensive digital toys riding BART to work, there is no scarcity of crime in the city by the bay.
#
# From Sunset to SOMA, and Marina to Excelsior, this competition's dataset provides nearly 12 years of crime reports from across all of San Francisco's neighborhoods. Given time and location, you must predict the category of crime that occurred.
#
# We're also encouraging you to explore the dataset visually. What can we learn about the city through visualizations like this Top Crimes Map? The top most up-voted scripts from this competition will receive official Kaggle swag as prizes.
#
# ![Police Line](https://kaggle2.blob.core.windows.net/competitions/kaggle/4458/media/sfcrime_banner.png)

# %% [markdown]
# # Load Data

# %%
import numpy as np
import pandas as pd

data = pd.read_csv("train.csv", parse_dates=['Dates'])
data = data.reindex(np.random.permutation(data.index)) 
data
# Out:
#                      Dates           Category  \
# 522695 2007-12-28 23:30:00      LARCENY/THEFT
# 534955 2007-10-21 17:00:00          VANDALISM
# 350355 2010-07-02 23:00:00     MISSING PERSON
# 62810  2014-07-13 06:11:00        WEAPON LAWS
# 699921 2005-06-14 09:20:00      LARCENY/THEFT
# 338493 2010-09-07 19:35:00       PROSTITUTION
# 182514 2012-12-11 21:00:00      VEHICLE THEFT
# 675831 2005-10-17 02:16:00           WARRANTS
# 270343 2011-09-10 15:50:00  RECOVERED VEHICLE
# 37482  2014-11-12 19:10:00     SUSPICIOUS OCC
# 345038 2010-07-31 18:00:00      LARCENY/THEFT
# 512247 2008-02-23 02:00:00      LARCENY/THEFT
# 190176 2012-11-01 19:30:00           WARRANTS
# 360454 2010-05-08 19:45:00      LARCENY/THEFT
# 680936 2005-09-20 22:15:00            ASSAULT
# 99707  2014-01-12 16:00:00     OTHER OFFENSES
# 680519 2005-09-21 22:05:00        WEAPON LAWS
# 54041  2014-08-23 16:00:00      LARCENY/THEFT
# 174786 2013-01-22 08:05:00           WARRANTS
# 709432 2005-04-23 09:50:00     OTHER OFFENSES
# 644334 2006-03-23 20:00:00      LARCENY/THEFT
# 211909 2012-07-15 17:50:00      DRUG/NARCOTIC
# 552891 2007-07-25 18:35:00      LARCENY/THEFT
# 23404  2015-01-21 23:00:00           BURGLARY
# 502581 2008-04-16 00:19:00     OTHER OFFENSES
# 232198 2012-04-04 10:00:00      LARCENY/THEFT
# 74790  2014-05-16 14:46:00      LARCENY/THEFT
# 343274 2010-08-12 13:00:00      LARCENY/THEFT
# 804018 2004-01-05 11:00:00           BURGLARY
# 187250 2012-11-15 18:00:00     MISSING PERSON
# ...                    ...                ...
# 237009 2012-03-08 17:30:00      LARCENY/THEFT
# 164317 2013-03-09 12:18:00            ASSAULT
# 602398 2006-10-30 13:20:00     OTHER OFFENSES
# 874839 2003-01-20 21:00:00       NON-CRIMINAL
# 453704 2008-12-22 20:45:00            ROBBERY
# 519595 2008-01-13 08:50:00          VANDALISM
# 669044 2005-11-16 13:00:00      VEHICLE THEFT
# 188982 2012-11-04 11:00:00     MISSING PERSON
# 483607 2008-07-23 10:30:00       NON-CRIMINAL
# 780622 2004-04-18 17:30:00           BURGLARY
# 261295 2011-11-01 19:00:00     SUSPICIOUS OCC
# 474694 2008-09-05 12:54:00      DRUG/NARCOTIC
# 692788 2005-07-16 18:00:00           BURGLARY
# 683668 2005-09-06 19:06:00           WARRANTS
# 740899 2004-10-31 15:50:00      VEHICLE THEFT
# 88179  2014-03-09 12:16:00       NON-CRIMINAL
# 419601 2009-06-22 16:10:00           BURGLARY
# 594122 2006-12-12 18:30:00      LARCENY/THEFT
# 506506 2008-03-22 12:58:00     OTHER OFFENSES
# 260441 2011-11-04 00:01:00              FRAUD
# 371774 2010-03-10 12:11:00      LARCENY/THEFT
# 163835 2013-03-10 16:55:00     OTHER OFFENSES
# 242227 2012-02-09 20:45:00      LARCENY/THEFT
# 717478 2005-03-12 22:00:00          VANDALISM
# 271971 2011-09-06 03:30:00      VEHICLE THEFT
# 708901 2005-04-24 17:00:00           WARRANTS
# 279345 2011-07-26 15:40:00           WARRANTS
# 204040 2012-08-25 21:03:00      LARCENY/THEFT
# 326692 2010-11-04 22:45:00      LARCENY/THEFT
# 118868 2013-10-06 19:30:00      LARCENY/THEFT
#
#                                                 Descript  DayOfWeek  \
# 522695                       PETTY THEFT FROM A BUILDING     Friday
# 534955                     MALICIOUS MISCHIEF, VANDALISM     Sunday
# 350355                                     MISSING ADULT     Friday
# 62810                          POSS OF PROHIBITED WEAPON     Sunday
# 699921                           PETTY THEFT SHOPLIFTING    Tuesday
# 338493                  SOLICITS FOR ACT OF PROSTITUTION    Tuesday
# 182514                                 STOLEN AUTOMOBILE    Tuesday
# 675831                                    WARRANT ARREST     Monday
# 270343             RECOVERED VEHICLE - STOLEN OUTSIDE SF   Saturday
# 37482                              SUSPICIOUS OCCURRENCE  Wednesday
# 345038                       GRAND THEFT FROM A BUILDING   Saturday
# 512247                           PETTY THEFT OF PROPERTY   Saturday
# 190176              ENROUTE TO DEPARTMENT OF CORRECTIONS   Thursday
# 360454                      PETTY THEFT FROM LOCKED AUTO   Saturday
# 680936                       INFLICT INJURY ON COHABITEE    Tuesday
# 99707                        MISCELLANEOUS INVESTIGATION     Sunday
# 680519      POSS OF DEADLY WEAPON WITH INTENT TO ASSAULT  Wednesday
# 54041                     PETTY THEFT FROM UNLOCKED AUTO   Saturday
# 174786                   ENROUTE TO OUTSIDE JURISDICTION    Tuesday
# 709432                                 TRAFFIC VIOLATION   Saturday
# 644334                      GRAND THEFT FROM LOCKED AUTO   Thursday
# 211909                                 SALE OF MARIJUANA     Sunday
# 552891                            PETTY THEFT WITH PRIOR  Wednesday
# 23404              BURGLARY OF RESIDENCE, UNLAWFUL ENTRY  Wednesday
# 502581                          TRAFFIC VIOLATION ARREST  Wednesday
# 232198                       PETTY THEFT FROM A BUILDING  Wednesday
# 74790                            PETTY THEFT SHOPLIFTING     Friday
# 343274                      GRAND THEFT FROM LOCKED AUTO   Thursday
# 804018       BURGLARY OF APARTMENT HOUSE, UNLAWFUL ENTRY     Monday
# 187250                                  MISSING JUVENILE   Thursday
# ...                                                  ...        ...
# 237009                           PETTY THEFT OF PROPERTY   Thursday
# 164317                         THREATENING PHONE CALL(S)   Saturday
# 602398                           BEYOND PARENTAL CONTROL     Monday
# 874839                                  LOCATED PROPERTY     Monday
# 453704                      ATTEMPTED ROBBERY WITH A GUN     Monday
# 519595                     MALICIOUS MISCHIEF, VANDALISM     Sunday
# 669044                                 STOLEN AUTOMOBILE  Wednesday
# 188982                                      FOUND PERSON     Sunday
# 483607                                     LOST PROPERTY  Wednesday
# 780622                BURGLARY, ATTEMPTED FORCIBLE ENTRY     Sunday
# 261295                           INVESTIGATIVE DETENTION    Tuesday
# 474694                   POSSESSION OF BASE/ROCK COCAINE     Friday
# 692788  BURGLARY,STORE UNDER CONSTRUCTION, ATT. FORCIBLE   Saturday
# 683668                                    WARRANT ARREST    Tuesday
# 740899                                 STOLEN AUTOMOBILE     Sunday
# 88179                       AIDED CASE, MENTAL DISTURBED     Sunday
# 419601               BURGLARY, HOT PROWL, UNLAWFUL ENTRY     Monday
# 594122                      GRAND THEFT FROM LOCKED AUTO    Tuesday
# 506506                                 TRAFFIC VIOLATION   Saturday
# 260441           FRAUDULENT USE OF AUTOMATED TELLER CARD     Friday
# 371774                           PETTY THEFT SHOPLIFTING  Wednesday
# 163835                    VIOLATION OF RESTRAINING ORDER     Sunday
# 242227                       GRAND THEFT FROM A BUILDING   Thursday
# 717478         MALICIOUS MISCHIEF, VANDALISM OF VEHICLES   Saturday
# 271971                                 STOLEN AUTOMOBILE    Tuesday
# 708901                                    WARRANT ARREST     Sunday
# 279345                                    WARRANT ARREST    Tuesday
# 204040                           PETTY THEFT SHOPLIFTING   Saturday
# 326692                           PETTY THEFT OF PROPERTY   Thursday
# 118868                           PETTY THEFT OF PROPERTY     Sunday
#
#         PdDistrict                        Resolution  \
# 522695        PARK                              NONE
# 534955     BAYVIEW                              NONE
# 350355     CENTRAL                           LOCATED
# 62810      MISSION                    ARREST, BOOKED
# 699921    SOUTHERN                    ARREST, BOOKED
# 338493     MISSION                     ARREST, CITED
# 182514   INGLESIDE                              NONE
# 675831    NORTHERN                    ARREST, BOOKED
# 270343     TARAVAL                              NONE
# 37482      BAYVIEW                              NONE
# 345038    RICHMOND                              NONE
# 512247     BAYVIEW                              NONE
# 190176     BAYVIEW                    ARREST, BOOKED
# 360454    RICHMOND                              NONE
# 680936    NORTHERN                              NONE
# 99707      TARAVAL                              NONE
# 680519    SOUTHERN                              NONE
# 54041      BAYVIEW                              NONE
# 174786   INGLESIDE                    ARREST, BOOKED
# 709432     MISSION                     ARREST, CITED
# 644334    NORTHERN                              NONE
# 211909        PARK                    ARREST, BOOKED
# 552891    SOUTHERN                    ARREST, BOOKED
# 23404     NORTHERN                              NONE
# 502581    RICHMOND                    ARREST, BOOKED
# 232198    SOUTHERN                              NONE
# 74790   TENDERLOIN                    ARREST, BOOKED
# 343274     TARAVAL                              NONE
# 804018     MISSION                              NONE
# 187250     BAYVIEW                              NONE
# ...            ...                               ...
# 237009     MISSION                              NONE
# 164317    RICHMOND                              NONE
# 602398     TARAVAL                              NONE
# 874839     CENTRAL                              NONE
# 453704   INGLESIDE                    ARREST, BOOKED
# 519595    SOUTHERN                              NONE
# 669044     BAYVIEW                              NONE
# 188982    SOUTHERN                              NONE
# 483607        PARK                              NONE
# 780622     CENTRAL                              NONE
# 261295    SOUTHERN                              NONE
# 474694    SOUTHERN                    ARREST, BOOKED
# 692788     MISSION                              NONE
# 683668     BAYVIEW                    ARREST, BOOKED
# 740899     TARAVAL                              NONE
# 88179      CENTRAL                 PSYCHOPATHIC CASE
# 419601   INGLESIDE                              NONE
# 594122    NORTHERN                              NONE
# 506506     MISSION                     ARREST, CITED
# 260441    NORTHERN      PROSECUTED BY OUTSIDE AGENCY
# 371774     CENTRAL                              NONE
# 163835     MISSION  COMPLAINANT REFUSES TO PROSECUTE
# 242227    SOUTHERN                              NONE
# 717478    SOUTHERN                              NONE
# 271971    NORTHERN                              NONE
# 708901    SOUTHERN                    ARREST, BOOKED
# 279345   INGLESIDE                    ARREST, BOOKED
# 204040     MISSION                              NONE
# 326692     CENTRAL                              NONE
# 118868     MISSION                              NONE
#
#                              Address           X          Y
# 522695    600 Block of DIVISADERO ST -122.437781  37.775483
# 534955     1200 Block of MARIPOSA ST -122.396168  37.763823
# 350355        600 Block of SUTTER ST -122.411069  37.788856
# 62810       300 Block of SHOTWELL ST -122.416082  37.762823
# 699921          200 Block of KING ST -122.393111  37.777310
# 338493             17TH ST / CAPP ST -122.418486  37.763495
# 182514        300 Block of MOSCOW ST -122.427008  37.721998
# 675831        900 Block of LARKIN ST -122.418065  37.786342
# 270343      700 Block of QUINTARA ST -122.473424  37.748818
# 37482       900 Block of CAROLINA ST -122.399638  37.755974
# 345038   3800 Block of CALIFORNIA ST -122.457540  37.785946
# 512247      700 Block of MARIPOSA ST -122.391303  37.764116
# 190176        100 Block of DAKOTA ST -122.395635  37.753565
# 360454           FULTON ST / 48TH AV -122.508822  37.771443
# 680936         1200 Block of TURK ST -122.428840  37.780973
# 99707          2000 Block of 35TH AV -122.493361  37.748800
# 680519        800 Block of BRYANT ST -122.403405  37.775421
# 54041      400 Block of BAY SHORE BL -122.406844  37.739401
# 174786      ALEMANY BL / FARRAGUT AV -122.451954  37.712056
# 709432         VALENCIA ST / 16TH ST -122.421886  37.764918
# 644334          600 Block of POLK ST -122.419021  37.782653
# 211909       1800 Block of HAIGHT ST -122.452706  37.769216
# 552891        800 Block of MARKET ST -122.406521  37.785063
# 23404    3500 Block of DIVISADERO ST -122.443252  37.802324
# 502581            25TH AV / GEARY BL -122.484732  37.780092
# 232198   0 Block of NEWMONTGOMERY ST -122.400593  37.787602
# 74790         0 Block of OFARRELL ST -122.405895  37.786734
# 343274         17TH AV / SANTIAGO ST -122.473683  37.745012
# 804018     200 Block of LEXINGTON ST -122.420651  37.759327
# 187250      800 Block of ARKANSAS ST -122.397848  37.755358
# ...                              ...         ...        ...
# 237009      1000 Block of POTRERO AV -122.406539  37.756486
# 164317         2400 Block of PINE ST -122.436141  37.787689
# 602398           0 Block of JULES AV -122.461163  37.719125
# 874839   900 Block of NORTH POINT ST -122.422858  37.805444
# 453704          0 Block of MURRAY ST -122.425724  37.733545
# 519595          200 Block of 12TH ST -122.416509  37.771616
# 669044         22ND ST / ILLINOIS ST -122.387316  37.758002
# 188982             0 Block of 5TH ST -122.407383  37.783372
# 483607  300 Block of BOWLINGGREEN DR -122.459385  37.768937
# 780622  1700 Block of LEAVENWORTH ST -122.416957  37.796831
# 261295            5TH ST / HOWARD ST -122.404934  37.781499
# 474694     400 Block of STEVENSON ST -122.408560  37.782586
# 692788      1900 Block of MISSION ST -122.419815  37.765843
# 683668      1600 Block of LASALLE AV -122.390244  37.737317
# 740899         1500 Block of 47TH AV -122.506870  37.757558
# 88179          700 Block of GEARY ST -122.415633  37.786359
# 419601          0 Block of CANYON DR -122.431220  37.708882
# 594122     1700 Block of BROADWAY ST -122.425883  37.795365
# 506506       2600 Block of BRYANT ST -122.409121  37.751979
# 260441   1700 Block of WASHINGTON ST -122.422077  37.793206
# 371774        200 Block of SUTTER ST -122.404014  37.789752
# 163835         3400 Block of 18TH ST -122.420495  37.761822
# 242227        800 Block of MARKET ST -122.407634  37.784189
# 717478            HOWARD ST / 1ST ST -122.396039  37.788537
# 271971      800 Block of OFARRELL ST -122.418751  37.785116
# 708901      1000 Block of BRANNAN ST -122.407258  37.769770
# 279345      3300 Block of MISSION ST -122.421644  37.742997
# 204040         2300 Block of 16TH ST -122.409530  37.765718
# 326692          GEARY ST / TAYLOR ST -122.411519  37.786941
# 118868         3900 Block of 24TH ST -122.430784  37.751448
#
# [878049 rows x 9 columns]

# %% [markdown]
# # Feature Engineering

# %%
preprocess_list = []

# %% [markdown]
# ## Encode Label

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
data['Category_Ecoded'] = label_encoder.fit_transform(data["Category"])
#add columns for encoded label and then if we don't need original column
#that time we will can drop the original columns

# 너무 작은 라벨은 가장 많은 값으로 바꿔버린다. (log_loss가 계산을 못 함)
data.loc[data['Category_Ecoded'] == 22, 'Category_Ecoded'] = 21
data.loc[data['Category_Ecoded'] == 33, 'Category_Ecoded'] = 21

data.head()
# Out:
#                      Dates        Category                       Descript  \
# 522695 2007-12-28 23:30:00   LARCENY/THEFT    PETTY THEFT FROM A BUILDING
# 534955 2007-10-21 17:00:00       VANDALISM  MALICIOUS MISCHIEF, VANDALISM
# 350355 2010-07-02 23:00:00  MISSING PERSON                  MISSING ADULT
# 62810  2014-07-13 06:11:00     WEAPON LAWS      POSS OF PROHIBITED WEAPON
# 699921 2005-06-14 09:20:00   LARCENY/THEFT        PETTY THEFT SHOPLIFTING
#
#        DayOfWeek PdDistrict      Resolution                     Address  \
# 522695    Friday       PARK            NONE  600 Block of DIVISADERO ST
# 534955    Sunday    BAYVIEW            NONE   1200 Block of MARIPOSA ST
# 350355    Friday    CENTRAL         LOCATED      600 Block of SUTTER ST
# 62810     Sunday    MISSION  ARREST, BOOKED    300 Block of SHOTWELL ST
# 699921   Tuesday   SOUTHERN  ARREST, BOOKED        200 Block of KING ST
#
#                  X          Y  Category_Ecoded
# 522695 -122.437781  37.775483               16
# 534955 -122.396168  37.763823               35
# 350355 -122.411069  37.788856               19
# 62810  -122.416082  37.762823               38
# 699921 -122.393111  37.777310               16

# %% [markdown]
# ### Encode PdDistrict

# %%
from sklearn.preprocessing import LabelEncoder

def preprocess_pd_district(data):
    label_encoder = LabelEncoder()
    data['PdDistrictEncoded'] = label_encoder.fit_transform(data["PdDistrict"])
    
preprocess_pd_district(data)
preprocess_list.append(preprocess_pd_district)

data.head()
# Out:
#                      Dates        Category                       Descript  \
# 522695 2007-12-28 23:30:00   LARCENY/THEFT    PETTY THEFT FROM A BUILDING
# 534955 2007-10-21 17:00:00       VANDALISM  MALICIOUS MISCHIEF, VANDALISM
# 350355 2010-07-02 23:00:00  MISSING PERSON                  MISSING ADULT
# 62810  2014-07-13 06:11:00     WEAPON LAWS      POSS OF PROHIBITED WEAPON
# 699921 2005-06-14 09:20:00   LARCENY/THEFT        PETTY THEFT SHOPLIFTING
#
#        DayOfWeek PdDistrict      Resolution                     Address  \
# 522695    Friday       PARK            NONE  600 Block of DIVISADERO ST
# 534955    Sunday    BAYVIEW            NONE   1200 Block of MARIPOSA ST
# 350355    Friday    CENTRAL         LOCATED      600 Block of SUTTER ST
# 62810     Sunday    MISSION  ARREST, BOOKED    300 Block of SHOTWELL ST
# 699921   Tuesday   SOUTHERN  ARREST, BOOKED        200 Block of KING ST
#
#                  X          Y  Category_Ecoded  PdDistrictEncoded
# 522695 -122.437781  37.775483               16                  5
# 534955 -122.396168  37.763823               35                  0
# 350355 -122.411069  37.788856               19                  1
# 62810  -122.416082  37.762823               38                  3
# 699921 -122.393111  37.777310               16                  7

# %% [markdown]
# ## Encode DayOfWeek

# %%
from sklearn.preprocessing import LabelEncoder

def preprocess_dayofweek(data):
    label_encoder = LabelEncoder()
    data['DayOfWeekEncoded'] = label_encoder.fit_transform(data["DayOfWeek"])
    
preprocess_dayofweek(data)
preprocess_list.append(preprocess_dayofweek)

data.head()
# Out:
#                      Dates        Category                       Descript  \
# 522695 2007-12-28 23:30:00   LARCENY/THEFT    PETTY THEFT FROM A BUILDING
# 534955 2007-10-21 17:00:00       VANDALISM  MALICIOUS MISCHIEF, VANDALISM
# 350355 2010-07-02 23:00:00  MISSING PERSON                  MISSING ADULT
# 62810  2014-07-13 06:11:00     WEAPON LAWS      POSS OF PROHIBITED WEAPON
# 699921 2005-06-14 09:20:00   LARCENY/THEFT        PETTY THEFT SHOPLIFTING
#
#        DayOfWeek PdDistrict      Resolution                     Address  \
# 522695    Friday       PARK            NONE  600 Block of DIVISADERO ST
# 534955    Sunday    BAYVIEW            NONE   1200 Block of MARIPOSA ST
# 350355    Friday    CENTRAL         LOCATED      600 Block of SUTTER ST
# 62810     Sunday    MISSION  ARREST, BOOKED    300 Block of SHOTWELL ST
# 699921   Tuesday   SOUTHERN  ARREST, BOOKED        200 Block of KING ST
#
#                  X          Y  Category_Ecoded  PdDistrictEncoded  \
# 522695 -122.437781  37.775483               16                  5
# 534955 -122.396168  37.763823               35                  0
# 350355 -122.411069  37.788856               19                  1
# 62810  -122.416082  37.762823               38                  3
# 699921 -122.393111  37.777310               16                  7
#
#         DayOfWeekEncoded
# 522695                 0
# 534955                 3
# 350355                 0
# 62810                  3
# 699921                 5

# %% [markdown]
# ## Date parsing

# %%
import time
from datetime import datetime

def preprocess_dates(data):
    data['Day'] = data['Dates'].dt.day
    data['Month'] = data['Dates'].dt.month
    data['Year'] = data['Dates'].dt.year
    data['Hour'] = data['Dates'].dt.hour
    data['Minute'] = data['Dates'].dt.minute

preprocess_dates(data)
preprocess_list.append(preprocess_dates)

data.head()
# Out:
#                      Dates        Category                       Descript  \
# 522695 2007-12-28 23:30:00   LARCENY/THEFT    PETTY THEFT FROM A BUILDING
# 534955 2007-10-21 17:00:00       VANDALISM  MALICIOUS MISCHIEF, VANDALISM
# 350355 2010-07-02 23:00:00  MISSING PERSON                  MISSING ADULT
# 62810  2014-07-13 06:11:00     WEAPON LAWS      POSS OF PROHIBITED WEAPON
# 699921 2005-06-14 09:20:00   LARCENY/THEFT        PETTY THEFT SHOPLIFTING
#
#        DayOfWeek PdDistrict      Resolution                     Address  \
# 522695    Friday       PARK            NONE  600 Block of DIVISADERO ST
# 534955    Sunday    BAYVIEW            NONE   1200 Block of MARIPOSA ST
# 350355    Friday    CENTRAL         LOCATED      600 Block of SUTTER ST
# 62810     Sunday    MISSION  ARREST, BOOKED    300 Block of SHOTWELL ST
# 699921   Tuesday   SOUTHERN  ARREST, BOOKED        200 Block of KING ST
#
#                  X          Y  Category_Ecoded  PdDistrictEncoded  \
# 522695 -122.437781  37.775483               16                  5
# 534955 -122.396168  37.763823               35                  0
# 350355 -122.411069  37.788856               19                  1
# 62810  -122.416082  37.762823               38                  3
# 699921 -122.393111  37.777310               16                  7
#
#         DayOfWeekEncoded  Day  Month  Year  Hour  Minute
# 522695                 0   28     12  2007    23      30
# 534955                 3   21     10  2007    17       0
# 350355                 0    2      7  2010    23       0
# 62810                  3   13      7  2014     6      11
# 699921                 5   14      6  2005     9      20

# %% [markdown]
# ## Scale/Normailze Features

# %%
#필요하면 여러개 feature들 노멀라이즈

# %% [markdown]
# # Cross validatae by multi-class logarithmic loss

# %%
from sklearn.cross_validation import KFold
from sklearn.metrics import log_loss

def multiclass_logloss_score(model, features, labels, num_folds = 5):
    kfolds = KFold(len(features), num_folds)
    
    total_score = 0.0
    
    for train_index, test_index in kfolds:
        train_features = features.iloc[train_index]
        test_features = features.iloc[test_index]
        train_labels = labels.iloc[train_index]
        test_labels = labels.iloc[test_index]
        
        model.fit(train_features, train_labels)
        prediction = model.predict_proba(test_features)
        
        score = log_loss(test_labels, prediction)
        total_score += score
        
    total_score = total_score / num_folds
    
    return total_score

# %% [markdown]
# # Prediction

# %% [markdown]
# ## Predict

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

feature_names = ["X", "Y", "PdDistrictEncoded", "DayOfWeekEncoded","Day", "Month", "Year", "Hour", "Minute"]
#배열로 넘김
label_name = "Category_Ecoded"
#컬럼 넘김

#tree10_score = multiclass_logloss_score(RandomForestClassifier(n_estimators = 10, n_jobs= -1), data[feature_names], data[label_name])
#tree40_score = multiclass_logloss_score(RandomForestClassifier(n_estimators = 40, n_jobs= -1), data[feature_names], data[label_name])
logistic_score = multiclass_logloss_score(LogisticRegression(n_jobs = -1), data[feature_names], data[label_name])
#tree100_score = multiclass_logloss_score(RandomForestClassifier(n_estimators = 100, n_jobs= -1), data[feature_names], data[label_name])
tree100_score = 10.0
#model 들 넘김
print("logistic = %.5f, tree100 = %.5f" % ( logistic_score ,tree100_score))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-e1310580625c> in <module>()
#      13 tree100_socre = 10.0
#      14 #model 들 넘김
# ---> 15 print("logistic = %.5f, tree100 = %.5f" % ( tree100_score))
#
# NameError: name 'tree100_score' is not defined

# %%
from sklearn.ensemble import RandomForestClassifier

feature_names = ["X", "Y", "PdDistrictEncoded", "DayOfWeekEncoded", "Month", "Year", "Hour", "Minute"]
#배열로 넘김
label_name = "Category_Ecoded"
#컬럼 넘김

tree200_score = multiclass_logloss_score(RandomForestClassifier(n_estimators = 200, n_jobs= -1), data[feature_names], data[label_name])

print "tree200 = %.5f" % (tree200_score)
# Out:
# tree200 = 8.20108

# %% [markdown]
# # Submit

# %%
from sklearn.ensemble import RandomForestClassifier


train = pd.read_csv("train.csv",parse_dates=['Dates'])
test = pd.read_csv("test.csv",parse_dates=['Dates'])

for preprocess_function in preprocess_list:
    preprocess_function(train)
    preprocess_function(test)
    
feature_names = ["X", "Y", "PdDistrictEncoded", "DayOfWeekEncoded", "Month", "Year", "Hour", "Minute"]
train.drop(["Descript", "DayOfWeek", "PdDistrict", "Resolution", "Dates"], axis = 1)

label_name = "Category"

model = RandomForestClassifier(n_estimators = 120, n_jobs = -1)
model.fit(train[feature_names], train[label_name])
prediction = model.predict_proba(test[feature_names])

label_columns = sorted(train[label_name].unique())

submit = pd.DataFrame(prediction)
submit.index.names = ["Id"]
submit.columns = label_columns

submit

# %%
from time import strftime, localtime

current_time = strftime("%Y.%m.%d %H.%M.%S", localtime())

submit.to_csv("tree_120_%s.csv" % current_time)
